# %% [markdown]
# ### Pandas Data Management
#
# Load data.

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# DataFrame Copy
df_original = df.copy()

# %% [markdown]
# #### Copy
#
# Recall from the last lesson, when we filled in missing values for median salary.
#
# Here let's make a new dataframe df_altered and only make changes to it.

# %%
# Create new dataframe
df_altered = df_original

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Let's fill in missing values with the median value.

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered.loc[:,'salary_year_avg'].fillna(median_salary)

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %% [markdown]
# Now let's inspect the altered DataFrame.

# %%
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# That was good...
#
# But what about the original...

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Holdup!! How the heck did df_original get altered!?!
#
# Well both the variables of df_original and df_altered are referencing the same DataFrame.

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                1841458942224
# ID of df_altered:                 1841458942224
# Are the two dataframes the same?  True

# %% [markdown]
# Instead we can use the .copy() method

# %%
df_original = df.copy()
df_altered = df_original.copy()

print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                1841979757584
# ID of df_altered:                 1841979758224
# Are the two dataframes the same?  False

# %% [markdown]
# Now when we do this same operation:

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# The original dataframe doesn't get altered!

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Now that we've created a copy of our data, we want to start our analysis. But if we have a large set of data we only want to take a subset of data to make it more manageable. We can use sample() to get a random sample of the data.

# %% [markdown]
# ### Sample
#
# #### Notes
#
#    - sample(): Random sample of items.
#
# #### Examples
#
# Let's get a random sample of the data. You could get a sample with a fixed row number.

# %%
df.sample(n=5)
# Out:
#          job_title_short                                          job_title  \
# 522561    Data Scientist  Data Research Science Masters Apprenticeship (...
# 582741  Business Analyst                                        QA Engineer
# 260401    Data Scientist                                  Sr Data Scientist
# 22433     Data Scientist                              Global Data Scientist
# 33262     Data Scientist            Synopsia/ Offre d'emploi Data Scientits
#
#                      job_location          job_via job_schedule_type  \
# 522561  West End, Southampton, UK     via LinkedIn         Full-time
# 582741            Shanghai, China  via Trabajo.org         Full-time
# 260401            San Antonio, TX        via BeBee         Full-time
# 22433                    Anywhere       via Indeed         Full-time
# 33262               Paris, France       via Indeed         Full-time
#
#         job_work_from_home       search_location     job_posted_date  \
# 522561               False        United Kingdom 2023-11-30 11:15:07
# 582741               False                 China 2023-04-18 09:49:27
# 260401               False  Texas, United States 2023-02-03 07:06:45
# 22433                 True                 Sudan 2023-01-12 14:21:58
# 33262                False                France 2023-12-14 13:15:15
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 522561                  False                 False  United Kingdom
# 582741                  False                 False           China
# 260401                  False                 False   United States
# 22433                   False                 False           Sudan
# 33262                   False                 False          France
#
#        salary_rate  salary_year_avg  salary_hour_avg         company_name  \
# 522561        None              NaN              NaN                  BBC
# 582741        None              NaN              NaN                 Wish
# 260401        None              NaN              NaN          H-E-B, L.P.
# 22433         None              NaN              NaN       Kimberly-Clark
# 33262         None              NaN              NaN  Synopsia Ingénierie
#
#                                                job_skills  \
# 522561                              ['python', 'express']
# 582741                       ['python', 'java', 'golang']
# 260401  ['python', 'r', 'sql', 'databricks', 'pyspark'...
# 22433   ['sql', 'r', 'python', 'azure', 'snowflake', '...
# 33262   ['sql', 'python', 'gcp', 'azure', 'oracle', 'p...
#
#                                           job_type_skills
# 522561  {'programming': ['python'], 'webframeworks': [...
# 582741      {'programming': ['python', 'java', 'golang']}
# 260401  {'cloud': ['databricks'], 'libraries': ['pyspa...
# 22433   {'analyst_tools': ['word', 'sap', 'powerpoint'...
# 33262   {'analyst_tools': ['power bi'], 'cloud': ['gcp...

# %% [markdown]
# Or you can randomly select a fraction of the data (e.g., 10% of the rows), with or without replacement.

# %%
df.sample(frac=0.1, replace=False)
# Out:
#               job_title_short  \
# 589880  Senior Data Scientist
# 322589          Data Engineer
# 751897           Data Analyst
# 514751           Data Analyst
# 163927         Data Scientist
# ...                       ...
# 614466    Senior Data Analyst
# 61896        Business Analyst
# 601253         Data Scientist
# 358091           Data Analyst
# 495798         Cloud Engineer
#
#                                                 job_title  \
# 589880                              Senior Data Scientist
# 322589                         Data Engineer - WeKnowtice
# 751897                  Audit Data & Analytics Specialist
# 514751                                    Fraud Analytics
# 163927  Entry/Junior Level Data Scientist/Python Progr...
# ...                                                   ...
# 614466                     Lead Risk Analytics Consultant
# 61896      Junior Business Analyst, Reporting & Analytics
# 601253  Director of Security Analytics Products / Lead...
# 358091                                 Sales Data Analyst
# 495798                                Head of Engineering
#
#                                              job_location             job_via  \
# 589880                        Bengaluru, Karnataka, India     via Trabajo.org
# 322589                                Almere, Netherlands          via Indeed
# 751897                             Amsterdam, Netherlands          via Indeed
# 514751  Kuala Lumpur, Federal Territory of Kuala Lumpu...  via BeBee Malaysia
# 163927                                        Houston, TX     via Trabajo.org
# ...                                                   ...                 ...
# 614466                                        Concord, CA        via The Muse
# 61896                   Taguig, Metro Manila, Philippines        via LinkedIn
# 601253                                     Warsaw, Poland        via LinkedIn
# 358091                                           Colombia     via Recruit.net
# 495798                                Copenhagen, Denmark     via Trabajo.org
#
#        job_schedule_type  job_work_from_home            search_location  \
# 589880         Full-time               False                      India
# 322589         Full-time               False                Netherlands
# 751897         Full-time               False                Netherlands
# 514751         Full-time               False                   Malaysia
# 163927         Full-time               False                      Sudan
# ...                  ...                 ...                        ...
# 614466         Full-time               False  California, United States
# 61896               None               False                Philippines
# 601253         Full-time               False                     Poland
# 358091         Full-time               False                   Colombia
# 495798         Full-time               False                    Denmark
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 589880 2023-08-02 09:13:40                  False                 False
# 322589 2023-02-20 17:22:48                   True                 False
# 751897 2023-09-19 13:02:43                  False                 False
# 514751 2023-10-05 11:31:34                   True                 False
# 163927 2023-07-19 15:35:59                  False                 False
# ...                    ...                    ...                   ...
# 614466 2023-08-02 12:01:31                   True                  True
# 61896  2023-04-14 06:55:06                  False                 False
# 601253 2023-08-26 09:44:07                  False                 False
# 358091 2023-02-15 00:15:04                   True                 False
# 495798 2023-04-06 11:25:13                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 589880          India        None              NaN              NaN
# 322589    Netherlands        None              NaN              NaN
# 751897    Netherlands        None              NaN              NaN
# 514751       Malaysia        None              NaN              NaN
# 163927          Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 614466  United States        None              NaN              NaN
# 61896     Philippines        None              NaN              NaN
# 601253         Poland        None              NaN              NaN
# 358091       Colombia        None              NaN              NaN
# 495798        Denmark        None              NaN              NaN
#
#                       company_name  \
# 589880                   LegalZoom
# 322589                  Move Ahead
# 751897                        KPMG
# 514751                      Shopee
# 163927               SynergisticIT
# ...                            ...
# 614466                 Wells Fargo
# 61896   Northern Trust Corporation
# 601253                        Visa
# 358091                     Frubana
# 495798                 SmallClaims
#
#                                                job_skills  \
# 589880                                            ['sql']
# 322589  ['python', 'sql', 'snowflake', 'azure', 'jenki...
# 751897                                        ['alteryx']
# 514751                                            ['sql']
# 163927  ['go', 'java', 'javascript', 'c++', 'sas', 'sa...
# ...                                                   ...
# 614466         ['sas', 'sas', 'sql', 'python', 'tableau']
# 61896                                             ['sql']
# 601253         ['python', 'java', 'golang', 'c++', 'sql']
# 358091                                   ['sql', 'excel']
# 495798                                               None
#
#                                           job_type_skills
# 589880                           {'programming': ['sql']}
# 322589  {'cloud': ['snowflake', 'azure'], 'other': ['j...
# 751897                     {'analyst_tools': ['alteryx']}
# 514751                           {'programming': ['sql']}
# 163927  {'analyst_tools': ['sas', 'tableau'], 'librari...
# ...                                                   ...
# 614466  {'analyst_tools': ['sas', 'tableau'], 'program...
# 61896                            {'programming': ['sql']}
# 601253  {'programming': ['python', 'java', 'golang', '...
# 358091  {'analyst_tools': ['excel'], 'programming': ['...
# 495798                                               None
#
# [78574 rows x 17 columns]

# %% [markdown]
# Now you can analyze these subsets of data.
